# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
import pandas as pd
import plotly.express as px

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/flipkart-laptops-skus/flipkart_laptops.csv

# %%
laptops_df = pd.read_csv("/kaggle/input/flipkart-laptops-skus/flipkart_laptops.csv", encoding='latin1')

# %%
laptops_df.head()
# Out:
#                                                 Name   Brand  Sellig Price  \
# 0  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...  Lenovo         36990
# 1  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  Lenovo         37990
# 2  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ASUS         32990
# 3  realme Book (Slim) Core i3 11th Gen - (8 GB/25...  realme         46990
# 4  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...    DELL         38990
#
#      MRP Discount  Ratings                 No_of_ratings  \
# 0  60890  39% off      4.2      670 Ratings & 54 Reviews
# 1  59390  36% off      4.2    3803 Ratings & 362 Reviews
# 2  45990  28% off      4.3    8727 Ratings & 876 Reviews
# 3  54999  14% off      4.4  11894 Ratings & 1773 Reviews
# 4  61202  36% off      4.3        65 Ratings & 6 Reviews
#
#                                              Details
# 0  ['Intel Core i3 Processor (11th Gen)' '8 GB DD...
# 1  ['Intel Core i3 Processor (11th Gen)' '8 GB DD...
# ...

# %%
laptops_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           414 non-null    object
#  1   Brand          414 non-null    object
#  2   Sellig Price   414 non-null    int64
#  3   MRP            414 non-null    int64
#  4   Discount       414 non-null    object
#  5   Ratings        414 non-null    float64
#  6   No_of_ratings  414 non-null    object
#  7   Details        414 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 26.0+ KB

# %%
laptops_df.nunique()
# Out:
# Name             404
# Brand             17
# Sellig Price     230
# MRP              305
# Discount          44
# Ratings           19
# No_of_ratings    329
# Details          385
# dtype: int64

# %%
# Most Expensive Laptop Details
laptops_df.loc[laptops_df['Sellig Price'] == laptops_df['Sellig Price'].max(), ['Name', 'Brand', 'Sellig Price','Discount','Ratings']]
# Out:
#                                                  Name  Brand  Sellig Price  \
# 51  APPLE 2021 Macbook Pro M1 Max - (32 GB/1 TB SS...  APPLE        309490
#
#    Discount  Ratings
# 51   6% off      4.3

# %%
#Top 10 Most expensive 
laptops_df.loc[:, ['Name', 'Brand', 'Sellig Price','Discount','Ratings']].sort_values(by='Sellig Price', ascending=False).head(10)
# Out:
#                                                   Name      Brand  \
# 51   APPLE 2021 Macbook Pro M1 Max - (32 GB/1 TB SS...      APPLE
# 255  APPLE 2021 Macbook Pro M1 Max - (32 GB/1 TB SS...      APPLE
# 361  ASUS Core i9 10th Gen - (32 GB/1 TB SSD/Window...       ASUS
# 307  ALIENWARE Core i7 10th Gen - (16 GB/1 TB SSD/W...  ALIENWARE
# 271  ASUS ROG Flow X13 (2021) Ryzen 9 Octa Core AMD...       ASUS
# 305  ASUS Core i7 10th Gen - (32 GB/1 TB SSD/Window...       ASUS
# 171  APPLE 2021 Macbook Pro M1 Pro - (16 GB/512 GB ...      APPLE
# 203  APPLE 2021 Macbook Pro M1 Pro - (16 GB/1 TB SS...      APPLE
# 156  APPLE 2021 Macbook Pro M1 Pro - (16 GB/1 TB SS...      APPLE
# 308  ALIENWARE Core i7 10th Gen - (16 GB/512 GB SSD...  ALIENWARE
#
#      Sellig Price Discount  Ratings
# 51         309490   6% off      4.3
# 255        306990   6% off      4.3
# 361        269990  17% off      4.8
# 307        250000  14% off      4.0
# 271        224990  35% off      5.0
# ...

# %%
# Cheapest Laptop Details
laptops_df.loc[laptops_df['Sellig Price'] == laptops_df['Sellig Price'].min(), ['Name', 'Brand', 'Sellig Price','Discount','Ratings']]
# Out:
#                                                   Name Brand  Sellig Price  \
# 233  ASUS Chromebook Flip Touch Celeron Dual Core -...  ASUS         14990
#
#     Discount  Ratings
# 233  53% off      4.0

# %%
#10 least expensive 
laptops_df.loc[:, ['Name', 'Brand', 'Sellig Price','Discount','Ratings']].sort_values(by='Sellig Price', ascending=False).tail(10)
# Out:
#                                                   Name    Brand  Sellig Price  \
# 247  ASUS Chromebook Flip Touch Celeron Dual Core -...     ASUS         24390
# 55   ASUS VivoBook 14 (2021) Celeron Dual Core - (4...     ASUS         23990
# 390  Lenovo IdeaPad 1 Celeron Dual Core 4th Gen - (...   Lenovo         23890
# 316  acer Extensa 15 Pentium Quad Core - (4 GB/256 ...     acer         23400
# 288  Lenovo IdeaPad 1 Celeron Dual Core - (4 GB/256...   Lenovo         23250
# 125  ASUS Pentium Quad Core - (4 GB/1 TB HDD/Window...     ASUS         22990
# 11   Infinix INBook X1 Neo Series Celeron Quad Core...  Infinix         22990
# 357  DELL Inspiron 15 3000 Pentium Quad Core - (4 G...     DELL         22990
# 58   Infinix INBook X1 Neo Series Celeron Quad Core...  Infinix         20990
# 233  ASUS Chromebook Flip Touch Celeron Dual Core -...     ASUS         14990
#
#     Discount  Ratings
# 247  21% off      4.0
# 55   29% off      4.0
# 390  40% off      3.9
# ...

# %%
# Laptops listed per brand
laptops_df['Brand'].value_counts()
# Out:
# ASUS         120
# DELL          70
# HP            63
# Lenovo        59
# acer          32
# MSI           22
# APPLE         19
# Infinix       14
# Vaio           3
# Nokia          3
# realme         2
# ALIENWARE      2
# RedmiBook      1
# SAMSUNG        1
# Mi             1
# lenovo         1
# MICROSOFT      1
# Name: Brand, dtype: int64

# %%
# Bar graph Brand Vs No. of Laptops (using plotly)
x = laptops_df['Brand'].value_counts().index
y = laptops_df['Brand'].value_counts().values

df = pd.DataFrame({'Brand':x,
                  'No':y })

fig = px.bar(df, 
             x='Brand', 
             y='No',
             color='Brand',
             title='Brand Vs No. of Laptops'
            )
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
def clean_discount(dis):
    new_dis = float(dis.rstrip("% off"))
    return new_dis
    
laptops_df['Discount'] = laptops_df['Discount'].apply(clean_discount)

# %%
# Laptop with most discount
laptops_df[laptops_df['Discount'] == laptops_df['Discount'].max()]
# Out:
#                                                   Name Brand  Sellig Price  \
# 233  ASUS Chromebook Flip Touch Celeron Dual Core -...  ASUS         14990
#
#        MRP  Discount  Ratings               No_of_ratings  \
# 233  31990      53.0      4.0  1553 Ratings & 251 Reviews
#
#                                                Details
# 233  ['Intel Celeron Dual Core Processor' '4 GB LPD...

# %%
# Laptop with least discount
laptops_df[laptops_df['Discount'] == laptops_df['Discount'].min()]
# Out:
#                                                   Name   Brand  Sellig Price  \
# 322  MSI Stealth Core i7 8th Gen - (16 GB/512 GB SS...     MSI        184790
# 365  DELL Inspiron 3501 Core i5 11th Gen - (8 GB/1 ...    DELL         67990
# 378  Lenovo Core i5 11th Gen - (16 GB/512 GB SSD/Wi...  Lenovo         77990
#
#         MRP  Discount  Ratings             No_of_ratings  \
# 322  189990       2.0      4.8     5 Ratings & 1 Reviews
# 365   69812       2.0      4.3  190 Ratings & 19 Reviews
# 378   80366       2.0      4.3    34 Ratings & 4 Reviews
#
#                                                Details
# 322  ['NVIDIA GeForce RTX 2060' 'Intel Core i7 Proc...
# 365  ['Intel Core i5 Processor (11th Gen)' '8 GB DD...
# 378  ['Intel Core i5 Processor (11th Gen)' '16 GB D...

# %%
# Most Expensive Asus Laptop
laptops_df[laptops_df['Brand'] == 'ASUS'].sort_values(by='Sellig Price', ascending=False).head(1)
# Out:
#                                                   Name Brand  Sellig Price  \
# 361  ASUS Core i9 10th Gen - (32 GB/1 TB SSD/Window...  ASUS        269990
#
#         MRP  Discount  Ratings          No_of_ratings  \
# 361  326990      17.0      4.8  8 Ratings & 1 Reviews
#
#                                                Details
# 361  ['Intel Core i9 Processor (10th Gen)' '32 GB D...

# %%
# Least Expensive Asus Laptop
laptops_df[laptops_df['Brand'] == 'ASUS'].sort_values(by='Sellig Price', ascending=False).tail(1)
# Out:
#                                                   Name Brand  Sellig Price  \
# 233  ASUS Chromebook Flip Touch Celeron Dual Core -...  ASUS         14990
#
#        MRP  Discount  Ratings               No_of_ratings  \
# 233  31990      53.0      4.0  1553 Ratings & 251 Reviews
#
#                                                Details
# 233  ['Intel Celeron Dual Core Processor' '4 GB LPD...

# %%
# Most Expensive Asus Laptop
laptops_df[laptops_df['Brand'] == 'DELL'].sort_values(by='Sellig Price', ascending=False).head(1)
# Out:
#                                                   Name Brand  Sellig Price  \
# 293  DELL G15 Core i7 12th Gen - (16 GB/1 TB SSD/Wi...  DELL        116490
#
#         MRP  Discount  Ratings          No_of_ratings  \
# 293  150636      22.0      4.6  5 Ratings & 2 Reviews
#
#                                                Details
# 293  ['Intel Core i7 Processor (12th Gen)' '16 GB D...

# %%
# Least Expensive Asus Laptop
laptops_df[laptops_df['Brand'] == 'DELL'].sort_values(by='Sellig Price', ascending=False).tail(1)
# Out:
#                                                   Name Brand  Sellig Price  \
# 357  DELL Inspiron 15 3000 Pentium Quad Core - (4 G...  DELL         22990
#
#        MRP  Discount  Ratings               No_of_ratings  \
# 357  24418       5.0      4.1  1299 Ratings & 186 Reviews
#
#                                                Details
# 357  ['Intel Pentium Quad Core Processor' '4 GB DDR...

# %%
# Most Expensive Asus Laptop
laptops_df[laptops_df['Brand'] == 'Lenovo'].sort_values(by='Sellig Price', ascending=False).head(1)
# Out:
#                                                   Name   Brand  Sellig Price  \
# 312  Lenovo Yoga Core i7 10th Gen - (16 GB/1 TB SSD...  Lenovo        169990
#
#         MRP  Discount  Ratings          No_of_ratings  \
# 312  223890      24.0      2.5  2 Ratings & 1 Reviews
#
#                                                Details
# 312  ['Intel Core i7 Processor (10th Gen)' '16 GB L...

# %%
# Least Expensive Asus Laptop
laptops_df[laptops_df['Brand'] == 'Lenovo'].sort_values(by='Sellig Price', ascending=False).tail(1)
# Out:
#                                                   Name   Brand  Sellig Price  \
# 288  Lenovo IdeaPad 1 Celeron Dual Core - (4 GB/256...  Lenovo         23250
#
#        MRP  Discount  Ratings             No_of_ratings  \
# 288  34890      33.0      3.7  522 Ratings & 28 Reviews
#
#                                                Details
# 288  ['Intel Celeron Dual Core Processor' '4 GB DDR...

# %%
# Most Expensive Asus Laptop
laptops_df[laptops_df['Brand'] == 'HP'].sort_values(by='Sellig Price', ascending=False).head(1)
# Out:
#                                                   Name Brand  Sellig Price  \
# 375  HP Spectre x360 Core i7 10th Gen - (16 GB/512 ...    HP        162990
#
#         MRP  Discount  Ratings          No_of_ratings  \
# 375  192977      15.0      3.3  3 Ratings & 1 Reviews
#
#                                                Details
# 375  ['Intel Core i7 Processor (10th Gen)' '16 GB D...

# %%
# Least Expensive Asus Laptop
laptops_df[laptops_df['Brand'] == 'HP'].sort_values(by='Sellig Price', ascending=False).tail(1)
# Out:
#                                                  Name Brand  Sellig Price  \
# 47  HP Athlon Dual Core 3050U - (8 GB/256 GB SSD/W...    HP         25990
#
#       MRP  Discount  Ratings             No_of_ratings  \
# 47  36359      28.0      3.9  486 Ratings & 45 Reviews
#
#                                               Details
# 47  ['AMD Athlon Dual Core Processor' '8 GB DDR4 R...

# %%
# Most Expensive Asus Laptop
laptops_df[laptops_df['Brand'] == 'acer'].sort_values(by='Sellig Price', ascending=False).head(1)
# Out:
#                                                   Name Brand  Sellig Price  \
# 218  acer Predator Helios 300 Core i7 12th Gen - (1...  acer        155490
#
#         MRP  Discount  Ratings          No_of_ratings  \
# 218  179999      13.0      5.0  4 Ratings & 0 Reviews
#
#                                                Details
# 218  ['Intel Core i7 Processor (12th Gen)' '16 GB D...

# %%
# Least Expensive Asus Laptop
laptops_df[laptops_df['Brand'] == 'acer'].sort_values(by='Sellig Price', ascending=False).tail(1)
# Out:
#                                                   Name Brand  Sellig Price  \
# 316  acer Extensa 15 Pentium Quad Core - (4 GB/256 ...  acer         23400
#
#        MRP  Discount  Ratings             No_of_ratings  \
# 316  34990      33.0      4.3  480 Ratings & 90 Reviews
#
#                                                Details
# 316  ['Intel Pentium Quad Core Processor' '4 GB DDR...

# %%
# Most Expensive Asus Laptop
laptops_df[laptops_df['Brand'] == 'APPLE'].sort_values(by='Sellig Price', ascending=False).head(1)
# Out:
#                                                  Name  Brand  Sellig Price  \
# 51  APPLE 2021 Macbook Pro M1 Max - (32 GB/1 TB SS...  APPLE        309490
#
#        MRP  Discount  Ratings           No_of_ratings  \
# 51  329900       6.0      4.3  12 Ratings & 4 Reviews
#
#                                               Details
# 51  ['Apple M1 Max Processor' '32 GB Unified Memor...

# %%
# Least Expensive Asus Laptop
laptops_df[laptops_df['Brand'] == 'APPLE'].sort_values(by='Sellig Price', ascending=False).tail(1)
# Out:
#                                                 Name  Brand  Sellig Price  \
# 8  APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/M...  APPLE         88990
#
#      MRP  Discount  Ratings               No_of_ratings  \
# 8  99900      10.0      4.7  8401 Ratings & 758 Reviews
#
#                                              Details
# 8  ['Apple M1 Processor' '8 GB DDR4 RAM' 'Mac OS ...

# %%
# Bar graph Brand Vs Most Expensive Laptop (using plotly)
expensive = laptops_df.groupby('Brand').max('Sellig Price')
x = expensive['Sellig Price'].index
y = expensive['Sellig Price'].values

df = pd.DataFrame({'Brand':x,
                  'Selling Price':y })

fig = px.bar(df, 
             x='Brand', 
             y='Selling Price',
             color='Brand',
             title='Brand Vs Most Expensive Laptop'
            )
fig.show()
# Out:
# <div>                            <div id="d63311e0-d1a2-445f-8dae-f00af999a907" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d63311e0-d1a2-445f-8dae-f00af999a907")) {                    Plotly.newPlot(                        "d63311e0-d1a2-445f-8dae-f00af999a907",                        [{"alignmentgroup":"True","hovertemplate":"Brand=%{x}<br>Selling Price=%{y}<extra></extra>","legendgroup":"ALIENWARE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ALIENWARE","offsetgroup":"ALIENWARE","orientation":"v","showlegend":true,"textposition":"auto","x":["ALIENWARE"],"xaxis":"x","y":[250000],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}<br>Selling Price=%{y}<extra></extra>","legendgroup":"APPLE","marker":{"co
# ...

# %%
# Bar graph Brand Vs Least Expensive Laptop (using plotly)
cheapest = laptops_df.groupby('Brand').min('Sellig Price')
x = cheapest['Sellig Price'].index
y = cheapest['Sellig Price'].values

df = pd.DataFrame({'Brand':x,
                  'Selling Price':y })

fig = px.bar(df, 
             x='Brand', 
             y='Selling Price',
             color='Brand',
             title='Brand Vs Least Expensive Laptop'
            )
fig.show()
# Out:
# <div>                            <div id="07f0f7d9-8374-4f07-b189-08de1eb79049" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07f0f7d9-8374-4f07-b189-08de1eb79049")) {                    Plotly.newPlot(                        "07f0f7d9-8374-4f07-b189-08de1eb79049",                        [{"alignmentgroup":"True","hovertemplate":"Brand=%{x}<br>Selling Price=%{y}<extra></extra>","legendgroup":"ALIENWARE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ALIENWARE","offsetgroup":"ALIENWARE","orientation":"v","showlegend":true,"textposition":"auto","x":["ALIENWARE"],"xaxis":"x","y":[199990],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}<br>Selling Price=%{y}<extra></extra>","legendgroup":"APPLE","marker":{"co
# ...

# %%
# Laptop with highest ratings
laptops_df[(laptops_df['Ratings'] == laptops_df['Ratings'].max())]
# Out:
#                                                   Name   Brand  Sellig Price  \
# 120  ASUS ROG Strix G15 with 90Whr Battery Ryzen 7 ...    ASUS        146990
# 151  DELL Ryzen 7 Octa Core AMD R7-5800H - (16 GB/5...    DELL         89081
# 153  ASUS ROG Strix G15 (2022) with 90Whr Battery R...    ASUS        140990
# 207  ASUS Touchscreen Core i3 12th Gen - (8 GB/512 ...    ASUS         47990
# 214  ASUS Core i5 11th Gen - (8 GB/256 GB SSD/Windo...    ASUS         45990
# 218  acer Predator Helios 300 Core i7 12th Gen - (1...    acer        155490
# 271  ASUS ROG Flow X13 (2021) Ryzen 9 Octa Core AMD...    ASUS        224990
# 281  acer Predator Helios 300 Core i9 11th Gen - (1...    acer        139990
# 285  Lenovo Core i3 10th Gen - (8 GB/256 GB SSD/Win...  Lenovo         38980
# 310  ASUS ROG Zephyrus M16 (2022) with 90Whr Batter...    ASUS        179990
# 325  ASUS VivoBook Pro 15 OLED Ryzen 7 Octa Core 58...    ASUS         94990
# ...

# %%
# Laptop with lowest ratings
laptops_df[laptops_df['Ratings'] == laptops_df['Ratings'].min()]
# Out:
#                                                   Name   Brand  Sellig Price  \
# 312  Lenovo Yoga Core i7 10th Gen - (16 GB/1 TB SSD...  Lenovo        169990
#
#         MRP  Discount  Ratings          No_of_ratings  \
# 312  223890      24.0      2.5  2 Ratings & 1 Reviews
#
#                                                Details
# 312  ['Intel Core i7 Processor (10th Gen)' '16 GB L...

# %%
def convert_rating(str1):
    new_str = str1.split(" ")[0]
    return int(new_str)
    
laptops_df['nor'] = laptops_df['No_of_ratings'].apply(convert_rating)

# %%
laptops_df.head()
# Out:
#                                                 Name   Brand  Sellig Price  \
# 0  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...  Lenovo         36990
# 1  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  Lenovo         37990
# 2  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ASUS         32990
# 3  realme Book (Slim) Core i3 11th Gen - (8 GB/25...  realme         46990
# 4  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...    DELL         38990
#
#      MRP  Discount  Ratings                 No_of_ratings  \
# 0  60890      39.0      4.2      670 Ratings & 54 Reviews
# 1  59390      36.0      4.2    3803 Ratings & 362 Reviews
# 2  45990      28.0      4.3    8727 Ratings & 876 Reviews
# 3  54999      14.0      4.4  11894 Ratings & 1773 Reviews
# 4  61202      36.0      4.3        65 Ratings & 6 Reviews
#
#                                              Details    nor
# 0  ['Intel Core i3 Processor (11th Gen)' '8 GB DD...    670
# ...

# %%
# Laptop with highest ratings based on above mean no of ratings
laptops_rating = laptops_df[(laptops_df['nor'] >= laptops_df['nor'].mean())]
laptops_rating[(laptops_rating['Ratings'] == laptops_rating['Ratings'].max())]
# Out:
#                                                  Name  Brand  Sellig Price  \
# 8   APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/M...  APPLE         88990
# 67  APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/M...  APPLE         94990
# 68  APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/M...  APPLE         88990
# 70  APPLE MacBook Air M1 - (8 GB/512 GB SSD/Mac OS...  APPLE        104990
#
#        MRP  Discount  Ratings               No_of_ratings  \
# 8    99900      10.0      4.7  8401 Ratings & 758 Reviews
# 67   99900       4.0      4.7  8401 Ratings & 758 Reviews
# 68   99900      10.0      4.7  8401 Ratings & 758 Reviews
# 70  110900       5.0      4.7  8401 Ratings & 758 Reviews
#
#                                               Details   nor
# 8   ['Apple M1 Processor' '8 GB DDR4 RAM' 'Mac OS ...  8401
# 67  ['Apple M1 Processor' '8 GB DDR4 RAM' 'Mac OS ...  8401
# 68  ['Apple M1 Processor' '8 GB DDR4 RAM' 'Mac OS ...  8401
# ...

# %%
# Laptop with lowest ratings based on above mean no of ratings
laptops_rating = laptops_df[(laptops_df['nor'] >= laptops_df['nor'].mean())]
laptops_rating[(laptops_rating['Ratings'] == laptops_rating['Ratings'].min())]
# Out:
#                                                   Name Brand  Sellig Price  \
# 125  ASUS Pentium Quad Core - (4 GB/1 TB HDD/Window...  ASUS         22990
#
#        MRP  Discount  Ratings               No_of_ratings  \
# 125  30990      25.0      3.7  3154 Ratings & 404 Reviews
#
#                                                Details   nor
# 125  ['Intel Pentium Quad Core Processor' '4 GB DDR...  3154

# %%
#Search with a feature 
#feature = str(input("Enter the feature of laptop to be serached: "))
feature = '8 GB'
laptops_df[laptops_df['Details'].str.contains(feature)]
# Out:
#                                                   Name   Brand  Sellig Price  \
# 0    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...  Lenovo         36990
# 1    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  Lenovo         37990
# 2    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ASUS         32990
# 3    realme Book (Slim) Core i3 11th Gen - (8 GB/25...  realme         46990
# 4    DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...    DELL         38990
# ..                                                 ...     ...           ...
# 407  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/1 TB...  Lenovo         35500
# 409  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...    DELL         45890
# 410  acer Swift 3 Core i5 11th Gen Intel EVO - (8 G...    acer         68500
# 412  ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 G...    ASUS         44490
# 413  DELL Inspiron Core i5 11th Gen - (8 GB/1 TB HD...    DELL         65990
#
# ...

# %% [markdown]
# **If you like my work, please Upvote.
# Thank You**
